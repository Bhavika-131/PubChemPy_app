# %%
# !pip install pubchempy
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pubchempy: filename=PubChemPy-1.0.4-py3-none-any.whl size=13819 sha256=5e09adbc4979bc76a75b8bc239007998773040935cf40a941d82cec0b37af3dd
#   Stored in directory: /home/ritesh/.cache/pip/wheels/b0/8c/ba/3b00b89931153bf5a4eaa8e73bd1b0319a879cc45175326854
# Successfully built pubchempy
# ...

# %%
# !pip install pandas

# %%
import pubchempy as pcp

# %%
c = pcp.Compound.from_cid(5090)
c
# Out:
# Compound(5090)

# %%
#print c.isomeric_smiles
print(c.isomeric_smiles)
# Out:
# CS(=O)(=O)C1=CC=C(C=C1)C2=C(C(=O)OC2)C3=CC=CC=C3

# %%
import csv
import pubchempy as pcp
import pandas as pd
import numpy as np

# %%
r = pcp.get_compounds('CC', 'smiles', searchtype='superstructure', listkey_count=3)
r
#print(r)
# Out:
# [Compound(297), Compound(783), Compound(5462310)]

# %%
#Define the SMILES string
smiles = 'CS(=O)(=O)C1=CC=C(C=C1)C2=C(C(=O)OC2)C3=CC=CC=C3'

# Search PubChem for the compound with the given SMILES string
results = pcp.get_compounds(smiles, 'smiles')

# Print the PubChem CID for the first result
print(results[0].cid)
# Out:
# 5090

# %%
smiles_list = pd.read_csv('smiles.csv')
smiles_list
# Out:
#                         smiles
# 0                      CSCCC=O
# 1                    CCC(C)C=O
# 2                 CC(=O)C(C)=O
# 3            CCCCC/C=C/C=C/C=O
# 4            CC1OC(=C(O)C1=O)C
# ..                         ...
# 218                   CCCSSCCC
# 219            CCOC(=O)CCC(C)C
# 220               CCOC(=O)CCSC
# 221  CCCC[C@@H](CC)CCC([O-])=O
# 222    COC1=C(C=C(C=C1)CC=C)OC
#
# [223 rows x 1 columns]

# %%
# List of SMILES strings
smiles_list = [ 
'CSCCC=O',
'CCC(C)C=O',
'CC(=O)C(C)=O',
'CCCCC/C=C/C=C/C=O',
'CC1OC(=C(O)C1=O)C',
'CCCCCC=O',
'CC1OC(=O)C(=C1C)O',
'CCCCCC(=O)C=C',
'CC(O)=O',
'CC=O',
'CCOC(=O)C(C)CC',
'CCCCCC\C=C\C=O',
'COC1=C(C=CC(=C1)C=O)O',
'CC(=O)C1=NCCC1',
'CCC(C)C(O)=O',
'CCCC(O)=O',
'CC(C)=CCCC(C)(O)C=C',
'C/C=C/C(=O)C1=C(C)C=CCC1(C)C',
'CCCC(=O)OCC',
'CC\C=C/CC=O',
'COC1=CC=CC=C1O',
'CC(C)C=O',
'CCCCCC1C(O1)C=CC=O',
'C1=CC=C(C=C1)CCO',
'C1=CC=C(C=C1)CC=O',
'CCOC(=O)C(C)C',
'CCCC\C=C\C=C\C=O',
'CCC1=NC=C(N=C1C)C',
'CSSSC',
'C1=CC=C(C=C1)CC(=O)O',
'CC\C=C/CC(=O)C=C',
'CCC1=NC=C(N=C1CC)C',
'CCCCCC(=O)OCC',
'CC/C=C/CC\C=C\C=O',
'C1=COC(=C1)CS',
'CC(C)C1=NC=CN=C1OC',
'CC(C)CCO',
'CCCCCC\C=C/C=O',
'CSC',
'COC1=C(C=CC(=C1)C=C)O',
'CS',
'CCC(=O)C(C)=O',
'CCCCCC1CCCC(=O)O1',
'CC/C=C/CCC=O',
'CCCCC[C@H]1CCC(=O)O1',
'CCCCCCCC=O',
'CCC1=CC(=C(C=C1)O)OC',
'CCCCCC(=O)C(C)C(=O)C',
'CC(=O)OCCC1=CC=CC=C1',
'CCO',
'CC1=CCC2CC1C2(C)C',
'CC(C)CC1=NC=CN=C1OC',
'CC(=O)C1=NCCS1',
'CCCCCCCC(=O)OCC',
'CC(C)=CCCC(=C)C=C',
'CCCCC\C=C/C=C/C=O',
'COC1=C(C=CC(=C1)CC=C)O',
'CCCCCCC1CCC(=O)O1',
'CCC=O',
'CC(=C)C1CCC(=CC1)C',
'CC(C)CCOC(C)=O',
'CCCC[C@H]1OC(=O)C[C@H]1C',
'CCCCCCCCC1CCC(=O)O1',
'CCCCCC(O)=O',
'CC(=O)/C=C/C1=C(C)CCCC1(C)C',
'CC1=C(C=CO1)S',
'CC1=CC=C(C=C1)O',
'CCC(C)C1=NC=CN=C1OC',
'CCCCCCCCC=O',
'CCC1OC(=C(O)C1=O)C',
'CCOC(C)OCC',
'C1=CC=C(C=C1)C(=O)CN',
'CCC(C)C(=O)OC',
'CC\C=C/CCO',
'CC1=CNC2=CC=CC=C12',
'CC(C)C(O)=O',
'CCCCCCCCCC=O',
'CCCCC\C=C/CC1CCC(=O)O1',
'CC(C)=CCC\C(C)=C\CO',
'CCC=CCC=CCC=O',
'CCC=CC=CC=CC=O',
'CCCCCCCCCC(O)=O',
'COC1=C(C=CC(=C1)CC=C)O',
'CCCCCCO',
'CCC(C)CO',
'CCCCCC1=CC=CC=N1',
'CC12CCC(CC1)C(C)(C)O2',
'CCC(S)C(C)=O',
'CC1C2CCC(=CC2OC1=O)C',
'CCC1=NC(=CN=C1C)C',
'CCC1=CC(=CC=C1)O',
'CCC/C=C/C=O',
'CSCCCO',
'CCCCCCCC(O)=O',
'CC1=CN=C(C(=N1)C)C',
'CCCCCCCC1CCCC(=O)O1',
'COC1=CC=C(C=C1)CC=C',
'CC1=C(C=CO1)SSC',
'CCCCO'
'CCCCC(O)=O',
'CCC1=CC=C(C=C1)O',
'CC=CC1=CC=C(C=C1)OC',
'CC1=CC(=C(C=C1)OC)O',
'COC1=CC=C(C=C1)C=O',
'CCCC(=O)OC',
'CC(C)CO',
'COC1=CC(=CC2=C1OCO2)CC=C',
'CCCC1CC=CC(=O)O1',
'C1=CC=C(C=C1)CCS',
'CCC(=O)C1=NCCC1',
'C1=CC=C(C=C1)C=CCO',
'CC(=O)C1=NC=CN=C1',
'CC(=O)C1=CCCCN1',
'CCOC(=O)C1CCCCC1',
'CCC1OC(=O)C(=C1C)O',
'CCCCCCOC(C)=O',
'CCC(C)C(C(=O)O)O',
'CC(C)C=CS',
'CC(C)(S)CCOC=O',
'CC(C)CCCCCCCCCCC=O',
'CCCC(S)CCO',
'CCCC(S)CCOC(C)=O',
'CSSSSC',
'C=CC1=CC=C(C=C1)O',
'CCCC\C=C\C=O',
'CC\C=C/CCOC(C)=O',
'CC(=C)C1=CC=C(C)CC1',
'COC1=C(C)OC(C)C1=O',
'CC1=CC=C(C=C1)C(=O)C',
'CC1=CC=C(C=C1)C(=C)C',
'CCCCC1CCC(=O)O1',
'CC(=C)[C@@H]1CC=C(C)C(=O)C1',
'CCCCCC(O)C=C',
'CC(C)[C@@H]1CCC(=C)C=C1',
'CCC(=O)C(C)S',
'CCCCCCC[C@H]1CCC(=O)O1',
'CCCCCCC\C=C\C=O',
'CCCC=CCCCCC=O',
'CCOC(=O)/C=C/C1=CC=CC=C1',
'CCOC(=O)C(C(C)C)O',
'CCCCC(=O)OCC',
'CC1(C2CCC(C2)(C1=O)C)C',
'CCCCCC(C)O',
'CC1=CC(=C(C=C1)O)OC',
'COC(=O)/C=C/C1=CC=CC=C1',
'CCCSSSC',
'CC(=O)CC(C)(C)S',
'CC/C=C/CC\C=C\CO',
'CCCCC\C=C/C=O',
'CCC(=O)C=C',
'CC(C)[C@H]1CC=C(C)C=C1',
'CC(C)[C@@H]1CC=C(C)C=C1',
'CC1(C)C2CCC(=C)C1C2',
'CCC(O)=O',
'CCCCC\C=C/C=C/C=C',
'CCCSSSCCC',
'CCOC(C)=O',
'CCCC(O)CC(=O)OCC',
'CCC(C)C(=O)C=CC',
'CCCCC(=O)C=C',
'CC(O)C(C)=O',
'C/C=C/C1=CC(=C(C=C1)O)OC',
'CC1=C(O)C(=O)C=CO1',
'CSCSC',
'COC1=C(C=C(C=C1)CC=C)OC',
'CCC(C)COC(C)=O',
'CCCC(=O)C(C)CC',
'CC1=CC=CC=C1O',
'CCC(C(C)CO)S',
'CCCCOC(C)=O',
'CCCC1=CC(=C(C=C1)O)OC',
'CC1CCOC(C1)C=C(C)C',
'CCCCCCCC\C=C\C=O',
'CCCC[C@H]1[C@@H](CC(=O)O1)C',
'CCCCCCC\C=C/C=O',
'CCC\C=C\C=C\CCCO',
'COC1=C(C(=CC=C1)OC)O',
'CC1=CN=C(C(=N1)C)C=C',
'CCC1=NC(=CN=C1C=C)C',
'CCOC(=O)C1=CC=CC=C1',
'CCCCCCCCCC(=O)OCC',
'CCC(C)C(C(=O)OCC)O',
'CCOC(=O)CC1=CC=CC=C1',
'CSCC=C',
'CCOC1=C(C=CC(=C1)C=O)O',
'S',
'CC1=CCC(CC1)C(C)(C)S',
'COC1=CC2=C(C=C1)C=CC(=O)O2',
'CC1=CN=C(C(=N1)C)OC',
'COCCC(C)(C)S',
'CCC(C)C(O)C(O)=O',
'COC(=O)C1=CC=CC=C1',
'COC(=O)C(C)C',
'CCCC[C@@H](C)CCC([O-])=O',
'CC(=CS)C',
'CSCC=C',
'CCCCCCCC(C)=O',
'CCCC1CCCC(=O)O1',
'C1=CC=C(C=C1)CCC(=O)O',
'CC(=O)OC/C=C/C1=CC=CC=C1',
'C1OC2=C(O1)C=C(C=C2)C=O',
'CCCOC(=O)[C@@H](C)CC',
'CC(C)[C@@]12CCC(=C)[C@@H]1C2',
'CC(C)[C@]12CCC(=C)[C@H]1C2',
'CC[C@@H](C)C(=O)CC',
'CC1=CC[C@@H](CC1)C(C)(C)O',
'C1=CSC(=C1)CS',
'C1=CC=C2C(=C1)C=CC(=O)O2',
'CC1=CC(OC1=O)(C)C',
'C/C=C/CC/C=C/C=C/C=C',
'CC(C)C1=CC=C(C=C1)C=O',
'CS[S](C)=O',
'C/C=C/C(=O)C1=C(C)CCCC1(C)C',
'C=CCS[S](=O)CC=C',
'CSSC',
'CC1=CC(=C(C=C1)O)C',
'CC1=C(C(=CC=C1)C)O',
'CCCSSCCC',
'CCOC(=O)CCC(C)C',
'CCOC(=O)CCSC',
'CCCC[C@@H](CC)CCC([O-])=O',
'COC1=C(C=C(C=C1)CC=C)OC',
    
]

# Loop through each SMILES string
for smiles in smiles_list:
    # Search PubChem for the compound with the given SMILES string
    results = pcp.get_compounds(smiles, 'smiles')
    # Print the PubChem CID for the first result
    print(results[0].cid)
# Out:
# 18635
# 7284
# 650
# 5283349
# 19309
# 6184
# 62835
# 61346
# 176
# 177
# 24020
# 5283335
# 1183
# 522834
# 8314
# 264
# 6549
# 5366074
# 7762
# 643941
# 460
# 6561
# 526708
# 6054
# 998
# 7342
# 5283339
# 26334
# 19310
# 999
# 6429343
# 28905
# 31265
# 636687
# 7363
# 33166
# 31260
# 5354833
# 1068
# 332
# 878
# 11747
# 12810
# 5283318
# 441574
# 454
# 62465
# 529481
# 7654
# 702
# 6654
# 32594
# 169110
# 7799
# 31253
# 6427087
# 3314
# 12813
# 527
# 22311
# 31276
# 41285
# 16821
# 8892
# 638014
# 34286
# 2879
# 520098
# 31289
# 33931
# 7765
# 11952
# 13357
# 5281167
# 6736
# 6590
# 8175
# 5352428
# 637566
# 519906
# 92083
# 2969
# 3314
# 8103
# 8723
# 16800
# 2758
# 62237
# 6427076
# 25916
# 12101
# 5281168
# 10448
# 379
# 26808
# 12844
# 8815
# 47649
# 43267436
# 31242
# 7703
# 14519
# 31244
# 12180
# 6560
# 4276
# 13949543
# 78126
# 529251
# 308
# 30914
# 520194
# 18686
# 61199
# 8908
# 164623
# 73455828
# 526487
# 3018619
# 521348
# 518810
# 79828
# 62453
# 5283316
# 5363388
# ...

# %%
print(len(results))
# Out:
# 1

# %%
type(results)
# Out:
# list

# %%
CID = pd.read_csv('P_CID.csv')
CID
# Out:
#        P_CID
# 0      18635
# 1       7284
# 2        650
# 3    5283349
# 4      19309
# ..       ...
# 216    12377
# 217   117477
# 218    61592
# 219  6997349
# 220     7127
#
# [221 rows x 1 columns]

# %%
df3 = pcp.get_properties(['xlogp', 'rotatable_bond_count', ], '18635', 'cid', as_dataframe=True)
df3
# Out:
#        XLogP  RotatableBondCount
# CID
# 18635    0.3                   3

# %%
cids = ['18635','7284','650','5283349','19309','6184','62835','61346','176','177','24020',
        '5283335','1183','522834','8314','264','6549','5366074','7762','643941','460','6561','526708',
        '6054','998','7342','5283339','26334','19310','999','6429343','28905','31265','636687','7363',
        '33166','31260','5354833','1068','332','878','11747','12810','5283318','441574','454','62465',
        '529481','7654','702','6654','32594','169110','7799','31253','6427087','3314','12813','527',
        '22311','31276','41285','16821','8892','638014','34286','2879','520098','31289','33931','7765',
        '11952','13357','5281167','6736','6590','8175','5352428','637566','519906','92083','2969','3314',
        '8103','8723','16800','2758','62237','6427076','25916','12101','5281168','10448','379','26808',
        '12844','8815','47649','43267436','31242','7703','14519','31244','12180','6560','4276','13949543',
        '78126','529251','308','30914','520194','18686','61199','8908','164623','73455828','526487',
        '3018619','521348','518810','79828','62453','5283316','5363388','176983','61325','8500','62385',
        '7704','439570','18827','442484','529635','441644','5283345','53683233','637758','520125','10882',
        '14525','10976','7144','637520','5319765','88290','5320191','6427080','15394','442482','443160','14896',
        '1032','5352367','22383','8857','61293','517791','520420','179','853433','8369','15380','7127','12209',
        '27470','335','6430888','31272','17739','27866','5283356','11105597','5354834','6433790','7041','6429268',
        '6431144','7165','8048','13026600','7590','66282','8467','402','6427135','10748','6429218','526195','164623',
        '7150','11039','6997332','12522204','66282','13187','12777','107','5282110','8438','54341446','11051711',
        '10887971','12488849','442501','80408','323','39738','101455070','326','95200','5374527','65036','12232',
        '7771','11335','12377','117477','61592','6997349','7127']

df3 = pcp.get_properties(['xlogp', 'rotatable_bond_count', 'MolecularWeight'], cids, 'cid', as_dataframe=True)
df3
# Out:
#         MolecularWeight  XLogP  RotatableBondCount
# CID
# 18635            104.17    0.3                   3
# 7284              86.13    1.1                   2
# 650               86.09   -1.3                   1
# 5283349          152.23    3.2                   6
# 19309            128.13    0.7                   0
# ...                 ...    ...                 ...
# 12377             150.3    2.7                   5
# 117477           144.21    2.1                   5
# 61592            148.23    1.1                   5
# 6997349          171.26    4.2                   6
# 7127             178.23    2.5                   4
#
# [221 rows x 3 columns]

# %%
df3.to_csv('logp_res.csv')
